# %%
import sys
import os

# Adding src path so we can import modules
src_path = os.path.abspath(os.path.join('..', '..',))

if src_path not in sys.path:
    sys.path.append(src_path)

# %%
from core.base_urls import SEARCHING_URL
from core.datasets import dataset_test_2
from utils.extracting import extract_doc_ids
from measures.precision import get_precision_at_k
from measures.recall import get_recall, get_avg_recall
from measures.map import get_ap_at_k, get_map
import requests

queries = dataset_test_2.queries_iter()
qrels = dataset_test_2.qrels_iter()

count = 0
recalls = []
aps = []

for query in queries:
    if count == 10:
        break

    query_id = query.query_id
    print(f'processing {query_id}')

    # get matching results
    search_text = query.text
    request_body = {
        'dataset_id': 1,
        'search_text': search_text,
    }
    response = requests.post(SEARCHING_URL, json = request_body)

    if response.status_code == 200:
        # get retrieved docs
        retrieved_docs = response.json()['data']
        retrieved_ids = extract_doc_ids(retrieved_docs)

        print('Retrieved IDs')
        print(retrieved_ids)

        # get relevant docs
        relevant_ids = [qrel.doc_id for qrel in qrels if qrel.query_id == query_id]
        # convert to int
        relevant_ids = [int(id) for id in relevant_ids]

        print('Relevant IDs')
        print(relevant_ids)

        # calc precision@10
        precision = get_precision_at_k(retrieved_ids, relevant_ids, 10)
        print(f'Precision@10 is: {precision}')

        # calc recall
        recall = get_recall(retrieved_ids, relevant_ids)
        print(f'Recall is: {recall}')
        recalls.append(recall)

        # calc ap@10
        ap = get_ap_at_k(retrieved_ids, relevant_ids, 10)
        print(f'AP@10 is: {ap}')
        aps.append(ap)
        print('-------------------------------------')

        count = count + 1

# calc for all queries' recalls
avg_recall = get_avg_recall(recalls)
print(f'Average Recall is: {avg_recall}')

# calc map
map = get_map(aps)
print(f'MAP@10 is: {map}')
# Out:
# processing 318
# Retrieved IDs
# [166713, 235401, 461212, 656307, 656349, 819359, 1596915, 1705696, 1718235, 2052128, 2205067, 4203560, 5148322, 6074403, 6118532, 7111108, 7740142, 8087084, 8149395, 8285812, 8442897, 9065270, 9470181, 10878224, 10962607, 12013019, 12082605, 12893070, 13262874, 14267188, 14363681, 15174186, 16232795, 16782848, 18953509, 20119327, 20288395, 25464283, 27420689, 28175961, 28193317, 28239331, 28362277, 28376975, 28487148, 28781093, 29147378, 31189253, 31213113, 31252141, 31520143, 32437202, 33136280, 33136641, 33713583, 34995029, 35097421, 35631568, 35687146, 37188077, 38043257, 38414781, 39755708, 41048976, 41957971, 42134828, 42421601, 43193290, 44104058, 44149815, 44809704, 45658670, 46363701, 47010123, 48675532, 49242277, 49550316, 50744636, 52010861, 54285054, 55873326, 56744456, 57702829, 57702962, 57703198, 58660738, 59514642, 61205946, 61268862, 63008243, 64230811, 64805112, 65000062, 65000925, 65021904, 66401973, 67032175, 68907371, 71538843, 71887283]
# Relevant IDs
# [317]
# Retrieved at 10
# [166713, 235401, 461212, 656307, 656349, 819359, 1596915, 1705696, 1718235, 2052128]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 378
# Retrieved IDs
# [30809, 430394, 1589300, 2001398, 2140071, 2142867, 2590783, 3383639, 4667468, 5929445, 6483271, 7200857, 9558041, 10096046, 11060809, 11954926, 11983951, 12268728, 12674856, 12758832, 13409966, 14319390, 14693530, 15057370, 15190528, 15607591, 17090332, 17856211, 18798884, 19163455, 19201493, 19509640, 19848329, 19862870, 20214962, 20341220, 20341315, 21324338, 22368520, 22508414, 22575283, 22644887, 25192149, 25785152, 25874687, 26286824, 27293037, 27788304, 28762086, 28840033, 29636981, 31195689, 31500369, 32400217, 32508765, 33275126, 35743487, 35807878, 36776028, 37193993, 37596124, 39551902, 39821634, 40936224, 44343394, 44381246, 45576135, 46301800, 46363930, 46780420, 47269810, 48140444, 48689539, 49591861, 49810178, 50146689, 51509077, 52478690, 52656978, 53147291, 54793775, 55131226, 55146699, 56008012, 56241944, 56663191, 57195575, 57835863, 59352674, 61595212, 62704702, 63243349, 63426137, 65556649, 67115312, 68479627, 69637970, 69661717, 69666581, 72035283]
# Relevant IDs
# []
# Retrieved at 10
# [30809, 430394, 1589300, 2001398, 2140071, 2142867, 2590783, 3383639, 4667468, 5929445]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 379
# Retrieved IDs
# [4726, 4727, 4728, 4729, 4730, 142456, 162149, 162147, 171478, 298705, 311765, 438269, 474750, 481605, 1052133, 1061565, 1241786, 1246278, 1259631, 1437575, 2213207, 2448847, 2560779, 2619910, 2808281, 3828251, 4276475, 4448434, 4448814, 4449393, 4763028, 4846576, 5040053, 5659710, 6121837, 6647483, 6648261, 6868140, 8641982, 8642062, 8915540, 9077943, 9452615, 9452933, 11557106, 12508528, 12715916, 12858015, 13375677, 14579825, 16625757, 16643402, 16757649, 19360428, 19537990, 20046666, 24126080, 26340083, 27704325, 27747672, 27747924, 27748151, 28011980, 28076129, 28575459, 30151647, 32838906, 32994398, 33308786, 35034748, 36906344, 39745370, 41697103, 42598084, 43742204, 44079493, 45343769, 45415110, 46324316, 47200019, 47369163, 48157764, 48769959, 50549808, 51352457, 51962114, 52144815, 53849321, 53860168, 54747106, 54902928, 55685717, 55711095, 55940452, 57125190, 60367006, 60713072, 64694188, 67119302, 67355394]
# Relevant IDs
# []
# Retrieved at 10
# [4726, 4727, 4728, 4729, 4730, 142456, 162149, 162147, 171478, 298705]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 399
# Retrieved IDs
# [75152, 670344, 892533, 2097531, 3121499, 3739583, 4557059, 5429219, 7192710, 7783771, 8505204, 9032076, 10748248, 12044503, 13399809, 13556556, 13716213, 13879723, 14143414, 14446815, 16896550, 18295179, 19765815, 20122555, 20124498, 21894622, 23297384, 24621983, 25553389, 26210348, 26601168, 27952405, 28149545, 28351831, 28362266, 30304757, 31271679, 32484499, 32533111, 32564405, 33013057, 33069556, 33324775, 33668179, 33832193, 34494221, 35453454, 35568192, 36779976, 36964283, 37061493, 37384281, 37585711, 38119877, 38199412, 40636895, 40880719, 41248636, 41999919, 43362609, 43443461, 44374029, 45443583, 45657065, 46621381, 47136506, 47237215, 47874540, 48786479, 49789276, 49973397, 50031607, 50417334, 50597708, 51547933, 51778588, 52158897, 52617832, 53364858, 54278491, 54612356, 54682531, 55620498, 56439880, 56837437, 60357262, 60673893, 61428896, 63032476, 65146960, 66204574, 67086991, 67271383, 67990395, 68439636, 69350031, 70071113, 70497230, 72072654, 72483964]
# Relevant IDs
# []
# Retrieved at 10
# [75152, 670344, 892533, 2097531, 3121499, 3739583, 4557059, 5429219, 7192710, 7783771]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 420
# Retrieved IDs
# [165373, 796221, 4684110, 5123459, 8650191, 8958755, 9398724, 11140719, 11465464, 11601653, 11703170, 12226500, 13517585, 13663937, 13909387, 15968238, 19200829, 19518154, 21266572, 21686356, 22587975, 24021944, 24241566, 24438841, 25081906, 25129197, 25722917, 25757168, 25778107, 26270198, 28131854, 28467638, 28809393, 29507687, 31026221, 32001752, 32068821, 32513458, 32516617, 33362915, 33471950, 34518421, 34589448, 35525826, 35766650, 36389725, 37322448, 37545968, 37924220, 40001993, 40075199, 40512350, 40712794, 41712112, 42440345, 42583287, 44200296, 44845810, 44879043, 44949610, 44949752, 45151009, 45151172, 45426698, 45426967, 48321644, 51851714, 52856922, 53130162, 53202155, 54212792, 54807522, 55036443, 57183491, 57427110, 57839966, 59040297, 59475382, 60273418, 61926134, 61981015, 62236877, 63000673, 63197061, 63204924, 63638302, 65125394, 66349546, 66825295, 66923742, 67076546, 67330763, 67541168, 67995111, 68416018, 68817534, 70056617, 70089619, 71274694, 72389988]
# Relevant IDs
# []
# Retrieved at 10
# [165373, 796221, 4684110, 5123459, 8650191, 8958755, 9398724, 11140719, 11465464, 11601653]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 540
# Retrieved IDs
# [236122, 496350, 983513, 1195169, 1462414, 1910311, 2469174, 2591364, 2729255, 3294536, 3577050, 3654603, 3895554, 4608195, 4634274, 4970156, 5406505, 5756611, 6732046, 7378197, 9919095, 10046824, 10527234, 10604153, 11342459, 12560877, 14350094, 14628621, 14647019, 15559041, 15779273, 15948971, 17163571, 19199701, 20701738, 21585634, 23434670, 23666635, 24343190, 27294066, 28360282, 28581124, 30552049, 30822652, 30838242, 32649225, 33199579, 33790053, 34578088, 36341731, 38466392, 38478521, 38564361, 38808261, 39037107, 40925056, 41868788, 43155816, 43670777, 44363950, 45056066, 47157231, 47637634, 47695876, 47925622, 48652881, 50010065, 51252441, 51432882, 52140724, 52471729, 52750688, 53313326, 53867500, 54873681, 55309296, 56440147, 57849670, 58083330, 58121564, 58891249, 59437749, 59576968, 59763135, 60261885, 60732430, 61514866, 61963799, 62369072, 62528663, 62807254, 64274627, 64568662, 65402834, 65537710, 65652373, 68006923, 68633195, 70838037, 72251759]
# Relevant IDs
# []
# Retrieved at 10
# [236122, 496350, 983513, 1195169, 1462414, 1910311, 2469174, 2591364, 2729255, 3294536]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 548
# Retrieved IDs
# [179638, 363131, 417140, 502183, 663227, 926565, 1196937, 1313597, 1802794, 2274914, 2444058, 2959270, 3467779, 3479936, 3504625, 4066146, 4147505, 4360918, 4540369, 5265389, 6243404, 6458332, 7415999, 8124639, 8235799, 8540512, 8771005, 8808311, 9999458, 10817318, 13592590, 13852375, 14566806, 17786810, 18385844, 18733480, 19080566, 19894956, 21434950, 22039722, 22138599, 23451503, 25035581, 25035697, 26972347, 27739690, 27948608, 29681566, 30701069, 30810259, 31462771, 31700569, 32056391, 32184038, 32290720, 32736341, 32791036, 32791308, 32989529, 33383136, 34586145, 37146311, 37619382, 38656046, 39537915, 40476283, 40757509, 41101658, 41966540, 42405429, 43000862, 43158106, 43983796, 45268921, 47283107, 48296740, 49890818, 51253289, 52252539, 54376810, 54502304, 54545764, 55234829, 55818848, 56493821, 57452773, 57828803, 58610219, 59689679, 60672969, 61157684, 62250441, 63196869, 64758674, 66109342, 66579724, 68688537, 69534281, 70315108, 71562245]
# Relevant IDs
# []
# Retrieved at 10
# [179638, 363131, 417140, 502183, 663227, 926565, 1196937, 1313597, 1802794, 2274914]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 609
# Retrieved IDs
# [74892, 2310134, 2917280, 2952496, 3837327, 4487208, 5263148, 5831566, 6735146, 8154195, 8452805, 8843714, 8961830, 10821674, 13323619, 13778319, 15708208, 18528894, 18916948, 19634884, 19712210, 19793772, 21243938, 22723305, 22947281, 24743696, 24816754, 27947257, 28239475, 29554930, 30016017, 30817913, 30872905, 31129911, 31156369, 31283561, 32029234, 33325142, 34928477, 35052587, 37585711, 37731483, 38234503, 39792834, 40136494, 40155353, 40425832, 40441520, 41463866, 41852603, 41870953, 41898408, 42064575, 42123980, 42204116, 42743216, 43465298, 44013113, 44114597, 44805521, 45452897, 45586602, 46692426, 47125388, 47537252, 47578843, 47966306, 51187750, 51267253, 51373519, 51564129, 52596916, 52945697, 53368380, 53936600, 53962985, 54351981, 54532520, 54729626, 56018146, 56354150, 56557500, 56669275, 56809246, 56856242, 59620606, 60330836, 60976195, 61467916, 61954011, 62389396, 63644343, 64191735, 66863096, 66873431, 67229583, 69525203, 70208793, 70241570, 71356056]
# Relevant IDs
# []
# Retrieved at 10
# [74892, 2310134, 2917280, 2952496, 3837327, 4487208, 5263148, 5831566, 6735146, 8154195]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 744
# Retrieved IDs
# [222259, 442675, 496299, 1973843, 2458475, 2906403, 3546654, 3744601, 4243613, 4622101, 5396289, 6103109, 9054462, 9857987, 10536121, 12405229, 13296220, 13955037, 14127676, 14895549, 16951372, 17562648, 20575512, 20619519, 21567328, 22538902, 22972300, 23069508, 24570655, 24643448, 26057655, 26613939, 27443027, 31105379, 33121513, 34352568, 35540180, 36489171, 37816960, 38564361, 39537915, 40123783, 40397811, 40588549, 40675567, 40719301, 42549115, 42666860, 42790593, 43313038, 43848967, 44267709, 44703931, 46198541, 47031903, 47703815, 48393220, 48644441, 48948045, 49703879, 49752148, 50518551, 51044217, 52721485, 53037986, 53189304, 53881625, 53922377, 55272268, 56152663, 57208624, 57820046, 58252440, 58824095, 59014433, 59162248, 59657342, 61152480, 61324979, 61595611, 62105983, 62926736, 62931179, 63025238, 63080715, 63407780, 63485039, 63608690, 66447854, 66948737, 67303196, 67323997, 68066280, 68082913, 68346811, 68505032, 68596859, 69328903, 71698980, 71937209]
# Relevant IDs
# []
# Retrieved at 10
# [222259, 442675, 496299, 1973843, 2458475, 2906403, 3546654, 3744601, 4243613, 4622101]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# processing 784
# Retrieved IDs
# [27098, 413157, 1456429, 1582000, 2226221, 3287888, 4569282, 5377390, 5991505, 6586251, 6599429, 6739637, 8259794, 8660363, 8843403, 9034707, 10172281, 10938283, 14198385, 16389361, 16435377, 16930213, 17231362, 18040146, 18513028, 18623322, 19856332, 20568484, 20696203, 20902945, 20927392, 21730571, 22687011, 23580343, 23669560, 23977758, 24041390, 25867629, 26066433, 27813251, 29141687, 30695447, 31912076, 33027500, 33494444, 33494517, 34795228, 34915159, 34954932, 35182078, 35298627, 35758260, 36178795, 36844669, 37232043, 39788812, 41057100, 41195589, 41683635, 41905161, 42415786, 43601234, 44128579, 44847105, 46754799, 47019412, 47367195, 47477333, 47717362, 48497009, 48550866, 49309939, 49661835, 49855171, 52561520, 53144941, 54196225, 54994687, 56673686, 58014363, 58028928, 59657342, 60616892, 60812407, 60860149, 63274840, 63687248, 64105266, 64810098, 67032700, 67255498, 67411333, 68147725, 68355480, 69650781, 69687475, 70530444, 70966208, 71284336, 71958727]
# Relevant IDs
# []
# Retrieved at 10
# [27098, 413157, 1456429, 1582000, 2226221, 3287888, 4569282, 5377390, 5991505, 6586251]
# Relevant and Retrieved
# []
# Precision@10 is: 0.0
# Recall is: 0.0
# AP@10 is: 0.0
# -------------------------------------
# Average Recall is: 0.0
# MAP@10 is: 0.0
